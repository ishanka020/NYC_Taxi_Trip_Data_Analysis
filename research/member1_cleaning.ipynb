# %%
from pyspark.sql import SparkSession
from pathlib import Path
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.sql.functions import col

# Create SparkSession in local mode
spark = SparkSession.builder \
    .appName("NYC Taxi Data") \
    .master("local[*]") \
    .getOrCreate()

# %%
df = spark.read.parquet("/home/ariso/Documents/bigDataAssignment/NYC_Taxi_Trip_Data_Analysis/data/rawData")

# %%
df.printSchema()
df.show(5)
print("Total rows:", df.count())
# Out:
# root
#  |-- VendorID: integer (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- tpep_dropoff_datetime: timestamp_ntz (nullable = true)
#  |-- passenger_count: long (nullable = true)
#  |-- trip_distance: double (nullable = true)
#  |-- RatecodeID: long (nullable = true)
#  |-- store_and_fwd_flag: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- fare_amount: double (nullable = true)
#  |-- extra: double (nullable = true)
#  |-- mta_tax: double (nullable = true)
#  |-- tip_amount: double (nullable = true)
#  |-- tolls_amount: double (nullable = true)
#  |-- improvement_surcharge: double (nullable = true)
#  |-- total_amount: double (nullable = true)
#  |-- congestion_surcharge: double (nullable = true)
#  |-- Airport_fee: double (nullable = true)
#
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |VendorID|tpep_pickup_datetime|tpep_dropoff_datetime|passenger_count|trip_distance|RatecodeID|store_and_fwd_flag|PULocationID|DOLocationID|payment_type|fare_amount|extra|mta_tax|tip_amount|tolls_amount|improvement_surcharge|total_amount|congestion_surcharge|Airport_fee|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# |       1| 2024-08-01 00:21:00|  2024-08-01 00:36:13|              1|          7.4|         1|                 N|         138|          80|           1|       28.9| 7.75|    0.5|      7.65|         0.0|                  1.0|        45.8|                 0.0|       1.75|
# |       2| 2024-08-01 00:20:01|  2024-08-01 00:41:47|              1|         9.91|         1|                 N|         138|         239|           1|       40.8|  6.0|    0.5|     11.55|        6.94|                  1.0|       71.04|                 2.5|       1.75|
# |       1| 2024-08-01 00:17:52|  2024-08-01 00:41:45|              0|         13.4|         1|                 N|         138|          88|           1|       52.0|10.25|    0.5|      15.0|         0.0|                  1.0|       78.75|                 2.5|       1.75|
# |       1| 2024-08-01 00:49:08|  2024-08-01 00:55:56|              0|          3.9|         1|                 N|         209|         137|           3|       17.0|  3.5|    0.5|       0.0|         0.0|                  1.0|        22.0|                 2.5|        0.0|
# |       1| 2024-08-01 00:38:52|  2024-08-01 00:42:34|              1|          0.4|         1|                 N|         148|         144|           2|        5.1|  3.5|    0.5|       0.0|         0.0|                  1.0|        10.1|                 2.5|        0.0|
# +--------+--------------------+---------------------+---------------+-------------+----------+------------------+------------+------------+------------+-----------+-----+-------+----------+------------+---------------------+------------+--------------------+-----------+
# only showing top 5 rows
# Total rows: 41169720

# %%
required_cols = [
    "tpep_pickup_datetime", "tpep_dropoff_datetime",
    "fare_amount", "PULocationID", "DOLocationID",
    "trip_distance", "passenger_count"
]

df_cleaned = df.dropna(subset=required_cols)

# %%
print("Total rows:", df_cleaned.count())
# Out:
# [Stage 87:===================================================>     (9 + 1) / 10]
# Total rows: 37078488

# %%
df_cleaned.select("fare_amount").describe().show()

#to see min max and get idea of outliers
# Out:
# [Stage 90:===================================================>     (9 + 1) / 10]
# +-------+-----------------+
# |summary|      fare_amount|
# +-------+-----------------+
# |  count|         37078488|
# |   mean|19.20668875062649|
# | stddev|80.71790255018425|
# |    min|          -2261.2|
# |    max|        335544.44|
# +-------+-----------------+

# %%
from pyspark.sql.functions import col, unix_timestamp

df_cleaned = df_cleaned.filter(
    (col("fare_amount") > 3) & #the lowest base fare 
    (col("fare_amount") < 400)
)
df_cleaned.count()
df_cleaned.select("fare_amount").describe().show()
# Out:
# [Stage 96:===================================================>     (9 + 1) / 10]
# +-------+------------------+
# |summary|       fare_amount|
# +-------+------------------+
# |  count|          36270722|
# |   mean| 19.95070509155673|
# | stddev|18.486513247902597|
# |    min|              3.01|
# |    max|            399.99|
# +-------+------------------+

# %%
df_cleaned.select("trip_distance").describe().show()
# Out:
# [Stage 99:===================================================>     (9 + 1) / 10]
# +-------+-----------------+
# |summary|    trip_distance|
# +-------+-----------------+
# |  count|         36270722|
# |   mean|3.516674062622483|
# | stddev|86.26801177718178|
# |    min|              0.0|
# |    max|        160244.91|
# +-------+-----------------+

# %%
df_cleaned = df_cleaned.filter(
  (col("trip_distance") > 0.62) & (col("trip_distance") < 120)
)
df_cleaned.count()
df_cleaned.select("trip_distance").describe().show()
# Out:
# [Stage 105:==================================================>     (9 + 1) / 10]
# +-------+------------------+
# |summary|     trip_distance|
# +-------+------------------+
# |  count|          32879037|
# |   mean|3.7118411993049785|
# | stddev|  4.66060959861165|
# |    min|              0.63|
# |    max|            119.83|
# +-------+------------------+

# %%
df_cleaned.select("passenger_count").describe().show()
# Out:
# [Stage 108:==================================================>     (9 + 1) / 10]
# +-------+------------------+
# |summary|   passenger_count|
# +-------+------------------+
# |  count|          32879037|
# |   mean|1.3374203143480146|
# | stddev|  0.81966492060485|
# |    min|                 0|
# |    max|                 9|
# +-------+------------------+

# %%
df_cleaned = df_cleaned.filter(
  (col("passenger_count") > 0) & (col("passenger_count") <= 4)
)
df_cleaned.count()
df_cleaned.select("passenger_count").describe().show()
# Out:
# [Stage 114:==================================================>     (9 + 1) / 10]
# +-------+------------------+
# |summary|   passenger_count|
# +-------+------------------+
# |  count|          32045905|
# |   mean|1.2890427965757247|
# | stddev|0.6403213072011842|
# |    min|                 1|
# |    max|                 4|
# +-------+------------------+

# %%
df_cleaned = df_cleaned.filter(
  col("tpep_dropoff_datetime") > col("tpep_pickup_datetime")
)
df_cleaned.count()
# Out:
# 32044504

# %%
df_cleaned.select("PULocationID").describe().show()
# Out:
# [Stage 120:==================================================>     (9 + 1) / 10]
# +-------+-----------------+
# |summary|     PULocationID|
# +-------+-----------------+
# |  count|         32044504|
# |   mean|164.3305944133197|
# | stddev|63.16955579303938|
# |    min|                1|
# |    max|              265|
# +-------+-----------------+

# %%
df_cleaned.select("DOLocationID").describe().show()
# Out:
# [Stage 123:==================================================>     (9 + 1) / 10]
# +-------+------------------+
# |summary|      DOLocationID|
# +-------+------------------+
# |  count|          32044504|
# |   mean|163.54524644850176|
# | stddev| 69.75035600012627|
# |    min|                 1|
# |    max|               265|
# +-------+------------------+

# %%
df_cleaned.select("tolls_amount").describe().show()
# Out:
# [Stage 129:==================================================>     (9 + 1) / 10]
# +-------+------------------+
# |summary|      tolls_amount|
# +-------+------------------+
# |  count|          32044504|
# |   mean|0.6783849951268689|
# | stddev|2.3813431464706625|
# |    min|               0.0|
# |    max|           1702.88|
# +-------+------------------+

# %%
df_cleaned = df_cleaned.filter(
    (col("tolls_amount") >= 0) &
    (col("tolls_amount") < 100)
)
df_cleaned.count()
# Out:
# 32044478

# %%
df_cleaned.select("tip_amount").describe().show()
# Out:
# [Stage 141:==================================================>     (9 + 1) / 10]
# +-------+------------------+
# |summary|        tip_amount|
# +-------+------------------+
# |  count|          32044465|
# |   mean|3.8411926949023423|
# | stddev| 4.169653697934459|
# |    min|               0.0|
# |    max|            477.05|
# +-------+------------------+

# %%
df_cleaned = df_cleaned.filter(
    (col("tip_amount") >= 0) &
    (col("tip_amount") < 50)
)

# %%
df_cleaned = df_cleaned.filter(
    (col("total_amount") > 0) &
    (col("total_amount") < 500)
)
df_cleaned.count()
# Out:
# 32036273

# %%
df_cleaned.select("extra").describe().show()
# Out:
# [Stage 156:==================================================>     (9 + 1) / 10]
# +-------+------------------+
# |summary|             extra|
# +-------+------------------+
# |  count|          32036273|
# |   mean|1.5884188179442729|
# | stddev|1.8517540685515177|
# |    min|             -3.25|
# |    max|             16.19|
# +-------+------------------+

# %%
df_cleaned.count()
# Out:
# 32036273

# %%
df_cleaned.write \
    .mode("overwrite") \
    .parquet("/home/ariso/Documents/bigDataAssignment/NYC_Taxi_Trip_Data_Analysis/data/cleanedData")
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 df_cleaned.write \
#       2     .mode("overwrite") \
#       3     .parquet("/home/ariso/Documents/bigDataAssignment/NYC_Taxi_Trip_Data_Analysis/data/cleanedData")
#
# File ~/.local/lib/python3.10/site-packages/pyspark/sql/classic/dataframe.py:195, in DataFrame.write(self)
#     193 @property
#     194 def write(self) -> DataFrameWriter:
# --> 195     return DataFrameWriter(self)
#
# File ~/.local/lib/python3.10/site-packages/pyspark/sql/readwriter.py:1199, in DataFrameWriter.__init__(self, df)
#    1197 self._df = df
#    1198 self._spark = df.sparkSession
# -> 1199 self._jwrite = df._jdf.write()
#
# File ~/.local/lib/python3.10/site-packages/py4j/java_gateway.py:1361, in JavaMember.__call__(self, *args)
#    1354 args_command, temp_args = self._build_args(*args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
# -> 1361 answer = self.gateway_client.send_command(command)
#    1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#
# File ~/.local/lib/python3.10/site-packages/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File ~/.local/lib/python3.10/site-packages/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File ~/.local/lib/python3.10/site-packages/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File ~/.local/lib/python3.10/site-packages/py4j/clientserver.py:438, in ClientServerConnection.connect_to_java_server(self)
#     435 if self.ssl_context:
#     436     self.socket = self.ssl_context.wrap_socket(
#     437         self.socket, server_hostname=self.java_address)
# --> 438 self.socket.connect((self.java_address, self.java_port))
#     439 self.stream = self.socket.makefile("rb")
#     440 self.is_connected = True
#
# ConnectionRefusedError: [Errno 111] Connection refused
